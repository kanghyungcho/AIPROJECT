# %%
# 데이터처리
from __future__ import print_function
import numpy as np
import pandas as pd
from IPython.display import display, HTML
import csv
import itertools
# 머신러닝 알고리즘 및 평가
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import pylab
import scipy as sp
import sklearn.preprocessing as preprocessing
import mglearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# 시각화
import seaborn as sns
import matplotlib.pyplot as plt

# %%
############# 데이터 불러오기
dat_dir = 'C:/'
day_dat = pd.read_csv(dat_dir+'day.csv')
hour_dat = pd.read_csv(dat_dir+'hour.csv')

# %%
hour_dat_weathersit_temp = []
key1_temp =[]

with open('C:/hour.csv', 'r') as f:
    reader = csv.reader(f)
    for key, group in itertools.groupby(reader, lambda i:i[1]):
        hour_dat_weathersit_temp.append(list(map(lambda i:i[9], group)))
        key1_temp.append(key)

hour_dat_weathersit_temp1 = pd.DataFrame(hour_dat_weathersit_temp)
key1_temp1 = pd.DataFrame(key1_temp)
hour_dat_weathersit = pd.DataFrame(np.concatenate((key1_temp1,hour_dat_weathersit_temp1), axis=1),columns = ['dteday','weathersit_0hr','weathersit_1hr','weathersit_2hr','weathersit_3hr','weathersit_4hr','weathersit_5hr',
                       'weathersit_6hr','weathersit_7hr','weathersit_8hr','weathersit_9hr','weathersit_10hr','weathersit_11hr',
                       'weathersit_12hr','weathersit_13hr','weathersit_14hr','weathersit_15hr','weathersit_16hr','weathersit_17hr',
                       'weathersit_18hr','weathersit_19hr','weathersit_20hr','weathersit_21hr','weathersit_22hr','weathersit_23hr'])
hour_dat_weathersit = hour_dat_weathersit.drop(0)

# %%
hour_dat_temp_temp = []
key1_temp =[]

with open('C:/hour.csv', 'r') as f:
    reader = csv.reader(f)
    for key, group in itertools.groupby(reader, lambda i:i[1]):
        hour_dat_temp_temp.append(list(map(lambda i:i[10], group)))
        key1_temp.append(key)

hour_dat_temp_temp1 = pd.DataFrame(hour_dat_temp_temp)
key1_temp1 = pd.DataFrame(key1_temp)
hour_dat_temp = pd.DataFrame(np.concatenate((key1_temp1,hour_dat_temp_temp1), axis=1),
                    columns = ['dteday','temp_0hr','temp_1hr','temp_2hr','temp_3hr','temp_4hr','temp_5hr',
                       'temp_6hr','temp_7hr','temp_8hr','temp_9hr','temp_10hr','temp_11hr',
                       'temp_12hr','temp_13hr','temp_14hr','temp_15hr','temp_16hr','temp_17hr',
                       'temp_18hr','temp_19hr','temp_20hr','temp_21hr','temp_22hr','temp_23hr'])
hour_dat_temp = hour_dat_temp.drop(0)

# %%
hour_dat_atemp_temp = []
key1_temp =[]

with open('C:/hour.csv', 'r') as f:
    reader = csv.reader(f)
    for key, group in itertools.groupby(reader, lambda i:i[1]):
        hour_dat_atemp_temp.append(list(map(lambda i:i[11], group)))
        key1_temp.append(key)

hour_dat_atemp_temp1 = pd.DataFrame(hour_dat_atemp_temp)
key1_temp1 = pd.DataFrame(key1_temp)
hour_dat_atemp = pd.DataFrame(np.concatenate((key1_temp1,hour_dat_atemp_temp1), axis=1),
                    columns = ['dteday','atemp_0hr','atemp_1hr','atemp_2hr','atemp_3hr','atemp_4hr','atemp_5hr',
                       'atemp_6hr','atemp_7hr','atemp_8hr','atemp_9hr','atemp_10hr','atemp_11hr',
                       'atemp_12hr','atemp_13hr','atemp_14hr','atemp_15hr','atemp_16hr','atemp_17hr',
                       'atemp_18hr','atemp_19hr','atemp_20hr','atemp_21hr','atemp_22hr','atemp_23hr'])
hour_dat_atemp = hour_dat_atemp.drop(0)

# %%
hour_dat_hum_temp = []
key1_temp =[]

with open('C:/hour.csv', 'r') as f:
    reader = csv.reader(f)
    for key, group in itertools.groupby(reader, lambda i:i[1]):
        hour_dat_hum_temp.append(list(map(lambda i:i[12], group)))
        key1_temp.append(key)

hour_dat_hum_temp1 = pd.DataFrame(hour_dat_hum_temp)
key1_temp1 = pd.DataFrame(key1_temp)
hour_dat_hum = pd.DataFrame(np.concatenate((key1_temp1,hour_dat_hum_temp1), axis=1),
                    columns = ['dteday','hum_0hr','hum_1hr','hum_2hr','hum_3hr','hum_4hr','hum_5hr',
                       'hum_6hr','hum_7hr','hum_8hr','hum_9hr','hum_10hr','hum_11hr',
                       'hum_12hr','hum_13hr','hum_14hr','hum_15hr','hum_16hr','hum_17hr',
                       'hum_18hr','hum_19hr','hum_20hr','hum_21hr','hum_22hr','hum_23hr'])
hour_dat_hum = hour_dat_hum.drop(0)

# %%
hour_dat_windspeed_temp = []
key1_temp =[]

with open('C:/hour.csv', 'r') as f:
    reader = csv.reader(f)
    for key, group in itertools.groupby(reader, lambda i:i[1]):
        hour_dat_windspeed_temp.append(list(map(lambda i:i[13], group)))
        key1_temp.append(key)

hour_dat_windspeed_temp1 = pd.DataFrame(hour_dat_windspeed_temp)
key1_temp1 = pd.DataFrame(key1_temp)
hour_dat_windspeed = pd.DataFrame(np.concatenate((key1_temp1,hour_dat_windspeed_temp1), axis=1),
                    columns = ['dteday','windspeed_0hr','windspeed_1hr','windspeed_2hr','windspeed_3hr','windspeed_4hr','windspeed_5hr',
                       'windspeed_6hr','windspeed_7hr','windspeed_8hr','windspeed_9hr','windspeed_10hr','windspeed_11hr',
                       'windspeed_12hr','windspeed_13hr','windspeed_14hr','windspeed_15hr','windspeed_16hr','windspeed_17hr',
                       'windspeed_18hr','windspeed_19hr','windspeed_20hr','windspeed_21hr','windspeed_22hr','windspeed_23hr'])
hour_dat_windspeed = hour_dat_windspeed.drop(0)

# %%
hour_dat_casual_temp = []
key1_temp =[]

with open('C:/hour.csv', 'r') as f:
    reader = csv.reader(f)
    for key, group in itertools.groupby(reader, lambda i:i[1]):
        hour_dat_casual_temp.append(list(map(lambda i:i[14], group)))
        key1_temp.append(key)

hour_dat_casual_temp1 = pd.DataFrame(hour_dat_casual_temp)
key1_temp1 = pd.DataFrame(key1_temp)
hour_dat_casual = pd.DataFrame(np.concatenate((key1_temp1,hour_dat_casual_temp1), axis=1),
                    columns = ['dteday','casual_0hr','casual_1hr','casual_2hr','casual_3hr','casual_4hr','casual_5hr',
                       'casual_6hr','casual_7hr','casual_8hr','casual_9hr','casual_10hr','casual_11hr',
                       'casual_12hr','casual_13hr','casual_14hr','casual_15hr','casual_16hr','casual_17hr',
                       'casual_18hr','casual_19hr','casual_20hr','casual_21hr','casual_22hr','casual_23hr'])
hour_dat_casual = hour_dat_casual.drop(0)

# %%
hour_dat_registered_temp = []
key1_temp =[]

with open('C:/hour.csv', 'r') as f:
    reader = csv.reader(f)
    for key, group in itertools.groupby(reader, lambda i:i[1]):
        hour_dat_registered_temp.append(list(map(lambda i:i[15], group)))
        key1_temp.append(key)

hour_dat_registered_temp1 = pd.DataFrame(hour_dat_registered_temp)
key1_temp1 = pd.DataFrame(key1_temp)
hour_dat_registered = pd.DataFrame(np.concatenate((key1_temp1,hour_dat_registered_temp1), axis=1),
                    columns = ['dteday','registered_0hr','registered_1hr','registered_2hr','registered_3hr','registered_4hr','registered_5hr',
                       'registered_6hr','registered_7hr','registered_8hr','registered_9hr','registered_10hr','registered_11hr',
                       'registered_12hr','registered_13hr','registered_14hr','registered_15hr','registered_16hr','registered_17hr',
                       'registered_18hr','registered_19hr','registered_20hr','registered_21hr','registered_22hr','registered_23hr'])
hour_dat_registered = hour_dat_registered.drop(0)

# %%
hour_dat_totalcnt_temp = []
key1_temp =[]

with open('C:/hour.csv', 'r') as f:
    reader = csv.reader(f)
    for key, group in itertools.groupby(reader, lambda i:i[1]):
        hour_dat_totalcnt_temp.append(list(map(lambda i:i[16], group)))
        key1_temp.append(key)

hour_dat_totalcnt_temp1 = pd.DataFrame(hour_dat_totalcnt_temp)
key1_temp1 = pd.DataFrame(key1_temp)
hour_dat_totalcnt = pd.DataFrame(np.concatenate((key1_temp1,hour_dat_totalcnt_temp1), axis=1),
                    columns = ['dteday','totalcnt_0hr','totalcnt_1hr','totalcnt_2hr','totalcnt_3hr','totalcnt_4hr','totalcnt_5hr',
                       'totalcnt_6hr','totalcnt_7hr','totalcnt_8hr','totalcnt_9hr','totalcnt_10hr','totalcnt_11hr',
                       'totalcnt_12hr','totalcnt_13hr','totalcnt_14hr','totalcnt_15hr','totalcnt_16hr','totalcnt_17hr',
                       'totalcnt_18hr','totalcnt_19hr','totalcnt_20hr','totalcnt_21hr','totalcnt_22hr','totalcnt_23hr'])
hour_dat_totalcnt = hour_dat_totalcnt.drop(0)

# %%
hour_dat_New = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(day_dat, hour_dat_weathersit, how='left', on='dteday')
                        , hour_dat_temp, how='left', on='dteday')
                        ,hour_dat_atemp, how='left', on='dteday')
                        ,hour_dat_hum, how='left', on='dteday')
                        ,hour_dat_windspeed, how='left', on='dteday')
                        ,hour_dat_casual, how='left', on='dteday')
                        ,hour_dat_registered, how='left', on='dteday')
                        ,hour_dat_totalcnt, how='left', on='dteday')
hour_dat_New
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# 11        12  2011-01-12       1   0     1        0        3           1
# ...

# %%
for i in range(hour_dat.shape[0]):
    
    if i <= 23: 
        k = 3
    elif i >= 17355:
        k = 17358
    else: 
        k = (int(i/24) * 24) + 3
    
    hour_dat.weathersit_3hr[i] = hour_dat.weathersit[k]
# Out:
# C:\Users\user\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in range(hour_dat.shape[0]):
    
    if i <= 23: 
        k = 4
    elif i >= 17355:
        k = 17359
    else: 
        k = (int(i/24) * 24) + 4
    
    hour_dat.weathersit_4hr[i] = hour_dat.weathersit[k]
# Out:
# C:\Users\user\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in range(hour_dat.shape[0]):
    
    if i <= 23: 
        k = 5
    elif i >= 17355:
        k = 17360
    else: 
        k = (int(i/24) * 24) + 5
    
    hour_dat.weathersit_5hr[i] = hour_dat.weathersit[k]
# Out:
# C:\Users\user\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in range(hour_dat.shape[0]):
    
    if i <= 23: 
        k = 6
    elif i >= 17355:
        k = 17361
    else: 
        k = (int(i/24) * 24) + 6
    
    hour_dat.weathersit_6hr[i] = hour_dat.weathersit[k]
# Out:
# C:\Users\user\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in range(hour_dat.shape[0]):
    
    if i <= 23: 
        k = 7
    elif i >= 17355:
        k = 17362
    else: 
        k = (int(i/24) * 24) + 7
    
    hour_dat.weathersit_7hr[i] = hour_dat.weathersit[k]
